# %% [markdown]
# # EDA steps:
# •	Import the Data-set
# •	slicing data
# •	Check data characters
# •	calculating statistics: mean, median, standard deviation
# •	basic plotting for data
# •	Correlation computation
#
# Data pre-processing steps:
# •	Check out and filled the missing values
# •	Import the Libraries
# •   Read the bureau data
# •	Handle /Create Dummy variable
# •   Group by function
# •   Logistic Regrssion
# •	Dimensionality reduction
# •	Clustering of similar observations

# %%
# Import the Data-set & Import the Libraries

# %%
# numpy and pandas for data manipulation
import pandas as pd
import numpy as np
# matplotlib and seaborn for plotting
import matplotlib
import matplotlib.pyplot as plt 
import seaborn as sns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Read Data

# %%
app_train = app_train.read.format('csv').options(header='true', inferSchema='true').load("/FileStore/tables/application_train.csv",header='infer')
print(app_train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">NameError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">&lt;command-498798941979501&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">----&gt; 1</span><span class="ansiyellow"> </span>app_train <span class="ansiyellow">=</span> app_train<span class="ansiyellow">.</span>read<span class="ansiyellow">.</span>format<span class="ansiyellow">(</span><span class="ansiblue">&apos;csv&apos;</span><span class="ansiyellow">)</span><span class="ansiyellow">.</span>options<span class="ansiyellow">(</span>header<span class="ansiyellow">=</span><span class="ansiblue">&apos;true&apos;</span><span class="ansiyellow">,</span> inferSchema<span class="ansiyellow">=</span><span class="ansiblue">&apos;true&apos;</span><span class="ansiyellow">)</span><span class="ansiyellow">.</span>load<span class="ansiyellow">(</span><span class="ansiblue">&quot;/FileStore/tables/application_train.csv&quot;</span><span class="ansiyellow">,</span>header<span class="ansiyellow">=</span><span class="ansiblue">&apos;infer&apos;</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">      2</span> print<span class="ansiyellow">(</span>app_train<span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansired">NameError</span>: name &apos;app_train&apos; is not defined</div>

# %%
app_test = pd.read_csv('C:/Users/peter/Desktop/Home Default/application_test.csv')
print(app_test)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">OSError</span>                                   Traceback (most recent call last)
# <span class="ansigreen">&lt;command-498798941979502&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">----&gt; 1</span><span class="ansiyellow"> </span>app_test <span class="ansiyellow">=</span> pd<span class="ansiyellow">.</span>read_csv<span class="ansiyellow">(</span><span class="ansiblue">&apos;C:/Users/peter/Desktop/Home Default/application_test.csv&apos;</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">      2</span> print<span class="ansiyellow">(</span>app_test<span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">parser_f</span><span class="ansiblue">(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)</span>
# <span class="ansigreen">    560</span>                     skip_blank_lines=skip_blank_lines)
# <span class="ansigreen">    561</span> <span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 562</span><span class="ansiyellow">         </span><span class="ansigreen">return</span> _read<span class="ansiyellow">(</span>filepath_or_buffer<span class="ansiyellow">,</span> kwds<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    563</span> <span class="ansiyellow"></span>
# <span class="ansigreen">    564</span>     parser_f<span class="ansiyellow">.</span>__name__ <span class="ansiyellow">=</span> name<span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">_read</span><span class="ansiblue">(filepath_or_buffer, kwds)</span>
# <span class="ansigreen">    313</span> <span class="ansiyellow"></span>
# <span class="ansigreen">    314</span>     <span class="ansired"># Create the parser.</span><span class="ansiyellow"></span><span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 315</span><span class="ansiyellow">     </span>parser <span class="ansiyellow">=</span> TextFileReader<span class="ansiyellow">(</span>filepath_or_buffer<span class="ansiyellow">,</span> <span class="ansiyellow">**</span>kwds<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    316</span> <span class="ansiyellow"></span>
# <span class="ansigreen">    317</span>     <span class="ansigreen">if</span> <span class="ansiyellow">(</span>nrows <span class="ansigreen">is</span> <span class="ansigreen">not</span> <span class="ansigreen">None</span><span class="ansiyellow">)</span> <span class="ansigreen">and</span> <span class="ansiyellow">(</span>chunksize <span class="ansigreen">is</span> <span class="ansigreen">not</span> <span class="ansigreen">None</span><span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">__init__</span><span class="ansiblue">(self, f, engine, **kwds)</span>
# <span class="ansigreen">    643</span>             self<span class="ansiyellow">.</span>options<span class="ansiyellow">[</span><span class="ansiblue">&apos;has_index_names&apos;</span><span class="ansiyellow">]</span> <span class="ansiyellow">=</span> kwds<span class="ansiyellow">[</span><span class="ansiblue">&apos;has_index_names&apos;</span><span class="ansiyellow">]</span><span class="ansiyellow"></span>
# <span class="ansigreen">    644</span> <span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 645</span><span class="ansiyellow">         </span>self<span class="ansiyellow">.</span>_make_engine<span class="ansiyellow">(</span>self<span class="ansiyellow">.</span>engine<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    646</span> <span class="ansiyellow"></span>
# <span class="ansigreen">    647</span>     <span class="ansigreen">def</span> close<span class="ansiyellow">(</span>self<span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">_make_engine</span><span class="ansiblue">(self, engine)</span>
# <span class="ansigreen">    797</span>     <span class="ansigreen">def</span> _make_engine<span class="ansiyellow">(</span>self<span class="ansiyellow">,</span> engine<span class="ansiyellow">=</span><span class="ansiblue">&apos;c&apos;</span><span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">    798</span>         <span class="ansigreen">if</span> engine <span class="ansiyellow">==</span> <span class="ansiblue">&apos;c&apos;</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 799</span><span class="ansiyellow">             </span>self<span class="ansiyellow">.</span>_engine <span class="ansiyellow">=</span> CParserWrapper<span class="ansiyellow">(</span>self<span class="ansiyellow">.</span>f<span class="ansiyellow">,</span> <span class="ansiyellow">**</span>self<span class="ansiyellow">.</span>options<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    800</span>         <span class="ansigreen">else</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">    801</span>             <span class="ansigreen">if</span> engine <span class="ansiyellow">==</span> <span class="ansiblue">&apos;python&apos;</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">__init__</span><span class="ansiblue">(self, src, **kwds)</span>
# <span class="ansigreen">   1211</span>         kwds<span class="ansiyellow">[</span><span class="ansiblue">&apos;allow_leading_cols&apos;</span><span class="ansiyellow">]</span> <span class="ansiyellow">=</span> self<span class="ansiyellow">.</span>index_col <span class="ansigreen">is</span> <span class="ansigreen">not</span> <span class="ansigreen">False</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1212</span> <span class="ansiyellow"></span>
# <span class="ansigreen">-&gt; 1213</span><span class="ansiyellow">         </span>self<span class="ansiyellow">.</span>_reader <span class="ansiyellow">=</span> _parser<span class="ansiyellow">.</span>TextReader<span class="ansiyellow">(</span>src<span class="ansiyellow">,</span> <span class="ansiyellow">**</span>kwds<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1214</span> <span class="ansiyellow"></s

# %% [markdown]
# Slicing data

# %%
app_train.head(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">NameError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">&lt;command-498798941979504&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">----&gt; 1</span><span class="ansiyellow"> </span>app_train<span class="ansiyellow">.</span>head<span class="ansiyellow">(</span><span class="ansicyan">5</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansired">NameError</span>: name &apos;app_train&apos; is not defined</div>

# %%
app_train.head(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">NameError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">&lt;command-498798941979505&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">----&gt; 1</span><span class="ansiyellow"> </span>app_train<span class="ansiyellow">.</span>head<span class="ansiyellow">(</span><span class="ansicyan">5</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansired">NameError</span>: name &apos;app_train&apos; is not defined</div>

# %% [markdown]
# Check data characters & calculating statistics: mean, median, standard deviation

# %%
app_train.describe()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">NameError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">&lt;command-498798941979507&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">----&gt; 1</span><span class="ansiyellow"> </span>app_train<span class="ansiyellow">.</span>describe<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansired">NameError</span>: name &apos;app_train&apos; is not defined</div>

# %%
app_train.describe()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">NameError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">&lt;command-498798941979508&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">----&gt; 1</span><span class="ansiyellow"> </span>app_train<span class="ansiyellow">.</span>describe<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansired">NameError</span>: name &apos;app_train&apos; is not defined</div>

# %%
app_train['TARGET'].value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">NameError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">&lt;command-498798941979509&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">----&gt; 1</span><span class="ansiyellow"> </span>app_train<span class="ansiyellow">[</span><span class="ansiblue">&apos;TARGET&apos;</span><span class="ansiyellow">]</span><span class="ansiyellow">.</span>value_counts<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansired">NameError</span>: name &apos;app_train&apos; is not defined</div>

# %%
print('AMT_INCOME_TOTAL Train',app_train['AMT_INCOME_TOTAL'].count())
print('AMT_INCOME_TOTAL Test',app_test['AMT_INCOME_TOTAL'].count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">NameError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">&lt;command-498798941979510&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">----&gt; 1</span><span class="ansiyellow"> </span>print<span class="ansiyellow">(</span><span class="ansiblue">&apos;AMT_INCOME_TOTAL Train&apos;</span><span class="ansiyellow">,</span>app_train<span class="ansiyellow">[</span><span class="ansiblue">&apos;AMT_INCOME_TOTAL&apos;</span><span class="ansiyellow">]</span><span class="ansiyellow">.</span>count<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">      2</span> print<span class="ansiyellow">(</span><span class="ansiblue">&apos;AMT_INCOME_TOTAL Test&apos;</span><span class="ansiyellow">,</span>app_test<span class="ansiyellow">[</span><span class="ansiblue">&apos;AMT_INCOME_TOTAL&apos;</span><span class="ansiyellow">]</span><span class="ansiyellow">.</span>count<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansired">NameError</span>: name &apos;app_train&apos; is not defined</div>

# %% [markdown]
# basic plotting for data

# %%
app_train['TARGET'].astype(int).plot.hist()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">NameError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">&lt;command-498798941979512&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">----&gt; 1</span><span class="ansiyellow"> </span>app_train<span class="ansiyellow">[</span><span class="ansiblue">&apos;TARGET&apos;</span><span class="ansiyellow">]</span><span class="ansiyellow">.</span>astype<span class="ansiyellow">(</span>int<span class="ansiyellow">)</span><span class="ansiyellow">.</span>plot<span class="ansiyellow">.</span>hist<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansired">NameError</span>: name &apos;app_train&apos; is not defined</div>

# %% [markdown]
# Correlation computation

# %%
# Find correlations with the target and sort
correlations = app_train.corr()['TARGET'].sort_values()

# Display correlations
print('Most Positive Correlations:\n', correlations.tail(20))
print('\nMost Negative Correlations:\n', correlations.head(20))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">NameError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">&lt;command-498798941979514&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">      1</span> <span class="ansired"># Find correlations with the target and sort</span><span class="ansiyellow"></span><span class="ansiyellow"></span>
# <span class="ansigreen">----&gt; 2</span><span class="ansiyellow"> </span>correlations <span class="ansiyellow">=</span> app_train<span class="ansiyellow">.</span>corr<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow">[</span><span class="ansiblue">&apos;TARGET&apos;</span><span class="ansiyellow">]</span><span class="ansiyellow">.</span>sort_values<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">      3</span> <span class="ansiyellow"></span>
# <span class="ansigreen">      4</span> <span class="ansired"># Display correlations</span><span class="ansiyellow"></span><span class="ansiyellow"></span>
# <span class="ansigreen">      5</span> print<span class="ansiyellow">(</span><span class="ansiblue">&apos;Most Positive Correlations:\n&apos;</span><span class="ansiyellow">,</span> correlations<span class="ansiyellow">.</span>tail<span class="ansiyellow">(</span><span class="ansicyan">20</span><span class="ansiyellow">)</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansired">NameError</span>: name &apos;app_train&apos; is not defined</div>

# %% [markdown]
# Correlation Heat Map

# %%
ext_data = app_train[['TARGET', 'EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3', 'DAYS_BIRTH']]
ext_data_corrs = ext_data.corr()
ext_data_corrs

plt.figure(figsize = (8, 6))

# Heatmap of correlations
sns.heatmap(ext_data_corrs, cmap = plt.cm.RdYlBu_r, vmin = -0.25, annot = True, vmax = 0.6)
plt.title('Correlation Heatmap');
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">NameError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">&lt;command-498798941979516&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">----&gt; 1</span><span class="ansiyellow"> </span>ext_data <span class="ansiyellow">=</span> app_train<span class="ansiyellow">[</span><span class="ansiyellow">[</span><span class="ansiblue">&apos;TARGET&apos;</span><span class="ansiyellow">,</span> <span class="ansiblue">&apos;EXT_SOURCE_1&apos;</span><span class="ansiyellow">,</span> <span class="ansiblue">&apos;EXT_SOURCE_2&apos;</span><span class="ansiyellow">,</span> <span class="ansiblue">&apos;EXT_SOURCE_3&apos;</span><span class="ansiyellow">,</span> <span class="ansiblue">&apos;DAYS_BIRTH&apos;</span><span class="ansiyellow">]</span><span class="ansiyellow">]</span><span class="ansiyellow"></span>
# <span class="ansigreen">      2</span> ext_data_corrs <span class="ansiyellow">=</span> ext_data<span class="ansiyellow">.</span>corr<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">      3</span> ext_data_corrs<span class="ansiyellow"></span>
# <span class="ansigreen">      4</span> <span class="ansiyellow"></span>
# <span class="ansigreen">      5</span> plt<span class="ansiyellow">.</span>figure<span class="ansiyellow">(</span>figsize <span class="ansiyellow">=</span> <span class="ansiyellow">(</span><span class="ansicyan">8</span><span class="ansiyellow">,</span> <span class="ansicyan">6</span><span class="ansiyellow">)</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansired">NameError</span>: name &apos;app_train&apos; is not defined</div>

# %% [markdown]
# Check out and filled the missing values

# %%
# Function to calculate missing values by column# Funct 
def missing_values_table(df):
        # Total missing values
        mis_val = df.isnull().sum()
        
        # Percentage of missing values
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        
        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        
        # Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        
        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        
        # Print some summary information
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        
        # Return the dataframe with missing information
        return mis_val_table_ren_columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
 # Missing values statistics
missing_values = missing_values_table(app_train)
missing_values.head(20)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">NameError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">&lt;command-498798941979519&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">      1</span> <span class="ansired"># Missing values statistics</span><span class="ansiyellow"></span><span class="ansiyellow"></span>
# <span class="ansigreen">----&gt; 2</span><span class="ansiyellow"> </span>missing_values <span class="ansiyellow">=</span> missing_values_table<span class="ansiyellow">(</span>app_train<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">      3</span> missing_values<span class="ansiyellow">.</span>head<span class="ansiyellow">(</span><span class="ansicyan">20</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansired">NameError</span>: name &apos;app_train&apos; is not defined</div>

# %% [markdown]
# Exploration of Bureau Data

# %%
bureau = pd.read_csv('C:/Users/peter/Desktop/Home Default/bureau.csv')
bureau.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">OSError</span>                                   Traceback (most recent call last)
# <span class="ansigreen">&lt;command-498798941979521&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">----&gt; 1</span><span class="ansiyellow"> </span>bureau <span class="ansiyellow">=</span> pd<span class="ansiyellow">.</span>read_csv<span class="ansiyellow">(</span><span class="ansiblue">&apos;C:/Users/peter/Desktop/Home Default/bureau.csv&apos;</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">      2</span> bureau<span class="ansiyellow">.</span>head<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">parser_f</span><span class="ansiblue">(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)</span>
# <span class="ansigreen">    560</span>                     skip_blank_lines=skip_blank_lines)
# <span class="ansigreen">    561</span> <span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 562</span><span class="ansiyellow">         </span><span class="ansigreen">return</span> _read<span class="ansiyellow">(</span>filepath_or_buffer<span class="ansiyellow">,</span> kwds<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    563</span> <span class="ansiyellow"></span>
# <span class="ansigreen">    564</span>     parser_f<span class="ansiyellow">.</span>__name__ <span class="ansiyellow">=</span> name<span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">_read</span><span class="ansiblue">(filepath_or_buffer, kwds)</span>
# <span class="ansigreen">    313</span> <span class="ansiyellow"></span>
# <span class="ansigreen">    314</span>     <span class="ansired"># Create the parser.</span><span class="ansiyellow"></span><span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 315</span><span class="ansiyellow">     </span>parser <span class="ansiyellow">=</span> TextFileReader<span class="ansiyellow">(</span>filepath_or_buffer<span class="ansiyellow">,</span> <span class="ansiyellow">**</span>kwds<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    316</span> <span class="ansiyellow"></span>
# <span class="ansigreen">    317</span>     <span class="ansigreen">if</span> <span class="ansiyellow">(</span>nrows <span class="ansigreen">is</span> <span class="ansigreen">not</span> <span class="ansigreen">None</span><span class="ansiyellow">)</span> <span class="ansigreen">and</span> <span class="ansiyellow">(</span>chunksize <span class="ansigreen">is</span> <span class="ansigreen">not</span> <span class="ansigreen">None</span><span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">__init__</span><span class="ansiblue">(self, f, engine, **kwds)</span>
# <span class="ansigreen">    643</span>             self<span class="ansiyellow">.</span>options<span class="ansiyellow">[</span><span class="ansiblue">&apos;has_index_names&apos;</span><span class="ansiyellow">]</span> <span class="ansiyellow">=</span> kwds<span class="ansiyellow">[</span><span class="ansiblue">&apos;has_index_names&apos;</span><span class="ansiyellow">]</span><span class="ansiyellow"></span>
# <span class="ansigreen">    644</span> <span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 645</span><span class="ansiyellow">         </span>self<span class="ansiyellow">.</span>_make_engine<span class="ansiyellow">(</span>self<span class="ansiyellow">.</span>engine<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    646</span> <span class="ansiyellow"></span>
# <span class="ansigreen">    647</span>     <span class="ansigreen">def</span> close<span class="ansiyellow">(</span>self<span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">_make_engine</span><span class="ansiblue">(self, engine)</span>
# <span class="ansigreen">    797</span>     <span class="ansigreen">def</span> _make_engine<span class="ansiyellow">(</span>self<span class="ansiyellow">,</span> engine<span class="ansiyellow">=</span><span class="ansiblue">&apos;c&apos;</span><span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">    798</span>         <span class="ansigreen">if</span> engine <span class="ansiyellow">==</span> <span class="ansiblue">&apos;c&apos;</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 799</span><span class="ansiyellow">             </span>self<span class="ansiyellow">.</span>_engine <span class="ansiyellow">=</span> CParserWrapper<span class="ansiyellow">(</span>self<span class="ansiyellow">.</span>f<span class="ansiyellow">,</span> <span class="ansiyellow">**</span>self<span class="ansiyellow">.</span>options<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    800</span>         <span class="ansigreen">else</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">    801</span>             <span class="ansigreen">if</span> engine <span class="ansiyellow">==</span> <span class="ansiblue">&apos;python&apos;</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">__init__</span><span class="ansiblue">(self, src, **kwds)</span>
# <span class="ansigreen">   1211</span>         kwds<span class="ansiyellow">[</span><span class="ansiblue">&apos;allow_leading_cols&apos;</span><span class="ansiyellow">]</span> <span class="ansiyellow">=</span> self<span class="ansiyellow">.</span>index_col <span class="ansigreen">is</span> <span class="ansigreen">not</span> <span class="ansigreen">False</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1212</span> <span class="ansiyellow"></span>
# <span class="ansigreen">-&gt; 1213</span><span class="ansiyellow">         </span>self<span class="ansiyellow">.</span>_reader <span class="ansiyellow">=</span> _parser<span class="ansiyellow">.</span>TextReader<span class="ansiyellow">(</span>src<span class="ansiyellow">,</span> <span class="ansiyellow">**</span>kwds<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1214</span> <span clas

# %%
bureau_balance = pd.read_csv('C:/Users/peter/Desktop/Home Default/bureau_balance.csv')
bureau_balance.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">OSError</span>                                   Traceback (most recent call last)
# <span class="ansigreen">&lt;command-498798941979522&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">----&gt; 1</span><span class="ansiyellow"> </span>bureau_balance <span class="ansiyellow">=</span> pd<span class="ansiyellow">.</span>read_csv<span class="ansiyellow">(</span><span class="ansiblue">&apos;C:/Users/peter/Desktop/Home Default/bureau_balance.csv&apos;</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">      2</span> bureau_balance<span class="ansiyellow">.</span>head<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">parser_f</span><span class="ansiblue">(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)</span>
# <span class="ansigreen">    560</span>                     skip_blank_lines=skip_blank_lines)
# <span class="ansigreen">    561</span> <span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 562</span><span class="ansiyellow">         </span><span class="ansigreen">return</span> _read<span class="ansiyellow">(</span>filepath_or_buffer<span class="ansiyellow">,</span> kwds<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    563</span> <span class="ansiyellow"></span>
# <span class="ansigreen">    564</span>     parser_f<span class="ansiyellow">.</span>__name__ <span class="ansiyellow">=</span> name<span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">_read</span><span class="ansiblue">(filepath_or_buffer, kwds)</span>
# <span class="ansigreen">    313</span> <span class="ansiyellow"></span>
# <span class="ansigreen">    314</span>     <span class="ansired"># Create the parser.</span><span class="ansiyellow"></span><span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 315</span><span class="ansiyellow">     </span>parser <span class="ansiyellow">=</span> TextFileReader<span class="ansiyellow">(</span>filepath_or_buffer<span class="ansiyellow">,</span> <span class="ansiyellow">**</span>kwds<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    316</span> <span class="ansiyellow"></span>
# <span class="ansigreen">    317</span>     <span class="ansigreen">if</span> <span class="ansiyellow">(</span>nrows <span class="ansigreen">is</span> <span class="ansigreen">not</span> <span class="ansigreen">None</span><span class="ansiyellow">)</span> <span class="ansigreen">and</span> <span class="ansiyellow">(</span>chunksize <span class="ansigreen">is</span> <span class="ansigreen">not</span> <span class="ansigreen">None</span><span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">__init__</span><span class="ansiblue">(self, f, engine, **kwds)</span>
# <span class="ansigreen">    643</span>             self<span class="ansiyellow">.</span>options<span class="ansiyellow">[</span><span class="ansiblue">&apos;has_index_names&apos;</span><span class="ansiyellow">]</span> <span class="ansiyellow">=</span> kwds<span class="ansiyellow">[</span><span class="ansiblue">&apos;has_index_names&apos;</span><span class="ansiyellow">]</span><span class="ansiyellow"></span>
# <span class="ansigreen">    644</span> <span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 645</span><span class="ansiyellow">         </span>self<span class="ansiyellow">.</span>_make_engine<span class="ansiyellow">(</span>self<span class="ansiyellow">.</span>engine<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    646</span> <span class="ansiyellow"></span>
# <span class="ansigreen">    647</span>     <span class="ansigreen">def</span> close<span class="ansiyellow">(</span>self<span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">_make_engine</span><span class="ansiblue">(self, engine)</span>
# <span class="ansigreen">    797</span>     <span class="ansigreen">def</span> _make_engine<span class="ansiyellow">(</span>self<span class="ansiyellow">,</span> engine<span class="ansiyellow">=</span><span class="ansiblue">&apos;c&apos;</span><span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">    798</span>         <span class="ansigreen">if</span> engine <span class="ansiyellow">==</span> <span class="ansiblue">&apos;c&apos;</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 799</span><span class="ansiyellow">             </span>self<span class="ansiyellow">.</span>_engine <span class="ansiyellow">=</span> CParserWrapper<span class="ansiyellow">(</span>self<span class="ansiyellow">.</span>f<span class="ansiyellow">,</span> <span class="ansiyellow">**</span>self<span class="ansiyellow">.</span>options<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    800</span>         <span class="ansigreen">else</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">    801</span>             <span class="ansigreen">if</span> engine <span class="ansiyellow">==</span> <span class="ansiblue">&apos;python&apos;</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">__init__</span><span class="ansiblue">(self, src, **kwds)</span>
# <span class="ansigreen">   1211</span>         kwds<span class="ansiyellow">[</span><span class="ansiblue">&apos;allow_leading_cols&apos;</span><span class="ansiyellow">]</span> <span class="ansiyellow">=</span> self<span class="ansiyellow">.</span>index_col <span class="ansigreen">is</span> <span class="ansigreen">not</span> <span class="ansigreen">False</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1212</span> <span class="ansiyellow"></span>
# <span class="ansigreen">-&gt; 1213</span><span class="ansiyellow">         </span>self<span class="ansiyellow">.</span>_reader <span class="ansiyellow">=</span> _parser<span class="ansiyellow">.</span>TextReader<span class="ansiyellow">(</span>src<span class="ansiyellow">,</span> <span class="ansiyellow">**</span>kwds<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">

# %% [markdown]
# Import the Libraries

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV 
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import Imputer 
from sklearn.preprocessing import scale 
# Suppress warnings from pandas
import warnings
warnings.filterwarnings('ignore')

plt.style.use('fivethirtyeight')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Group By Function

# %%
# Groupby the client id (SK_ID_CURR), count the number of previous loans, and rename the column
previous_loan_counts = bureau.groupby('SK_ID_CURR', as_index=False)['SK_ID_BUREAU'].count().rename(columns = {'SK_ID_BUREAU': 'previous_loan_counts'})
previous_loan_counts.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">NameError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">&lt;command-498798941979526&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">      1</span> <span class="ansired"># Groupby the client id (SK_ID_CURR), count the number of previous loans, and rename the column</span><span class="ansiyellow"></span><span class="ansiyellow"></span>
# <span class="ansigreen">----&gt; 2</span><span class="ansiyellow"> </span>previous_loan_counts <span class="ansiyellow">=</span> bureau<span class="ansiyellow">.</span>groupby<span class="ansiyellow">(</span><span class="ansiblue">&apos;SK_ID_CURR&apos;</span><span class="ansiyellow">,</span> as_index<span class="ansiyellow">=</span><span class="ansigreen">False</span><span class="ansiyellow">)</span><span class="ansiyellow">[</span><span class="ansiblue">&apos;SK_ID_BUREAU&apos;</span><span class="ansiyellow">]</span><span class="ansiyellow">.</span>count<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow">.</span>rename<span class="ansiyellow">(</span>columns <span class="ansiyellow">=</span> <span class="ansiyellow">{</span><span class="ansiblue">&apos;SK_ID_BUREAU&apos;</span><span class="ansiyellow">:</span> <span class="ansiblue">&apos;previous_loan_counts&apos;</span><span class="ansiyellow">}</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">      3</span> previous_loan_counts<span class="ansiyellow">.</span>head<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansired">NameError</span>: name &apos;bureau&apos; is not defined</div>

# %%
import pandas as pd
# Join to the training dataframe
train = pd.read_csv('C:/Users/peter/Desktop/Home Default/application_train.csv')
train = train.merge(previous_loan_counts, on = 'SK_ID_CURR', how = 'left')

# Fill the missing values with 0 
train['previous_loan_counts'] = train['previous_loan_counts'].fillna(0)
train.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">OSError</span>                                   Traceback (most recent call last)
# <span class="ansigreen">&lt;command-498798941979527&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">      1</span> <span class="ansigreen">import</span> pandas <span class="ansigreen">as</span> pd<span class="ansiyellow"></span>
# <span class="ansigreen">      2</span> <span class="ansired"># Join to the training dataframe</span><span class="ansiyellow"></span><span class="ansiyellow"></span>
# <span class="ansigreen">----&gt; 3</span><span class="ansiyellow"> </span>train <span class="ansiyellow">=</span> pd<span class="ansiyellow">.</span>read_csv<span class="ansiyellow">(</span><span class="ansiblue">&apos;C:/Users/peter/Desktop/Home Default/application_train.csv&apos;</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">      4</span> train <span class="ansiyellow">=</span> train<span class="ansiyellow">.</span>merge<span class="ansiyellow">(</span>previous_loan_counts<span class="ansiyellow">,</span> on <span class="ansiyellow">=</span> <span class="ansiblue">&apos;SK_ID_CURR&apos;</span><span class="ansiyellow">,</span> how <span class="ansiyellow">=</span> <span class="ansiblue">&apos;left&apos;</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">      5</span> <span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">parser_f</span><span class="ansiblue">(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)</span>
# <span class="ansigreen">    560</span>                     skip_blank_lines=skip_blank_lines)
# <span class="ansigreen">    561</span> <span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 562</span><span class="ansiyellow">         </span><span class="ansigreen">return</span> _read<span class="ansiyellow">(</span>filepath_or_buffer<span class="ansiyellow">,</span> kwds<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    563</span> <span class="ansiyellow"></span>
# <span class="ansigreen">    564</span>     parser_f<span class="ansiyellow">.</span>__name__ <span class="ansiyellow">=</span> name<span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">_read</span><span class="ansiblue">(filepath_or_buffer, kwds)</span>
# <span class="ansigreen">    313</span> <span class="ansiyellow"></span>
# <span class="ansigreen">    314</span>     <span class="ansired"># Create the parser.</span><span class="ansiyellow"></span><span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 315</span><span class="ansiyellow">     </span>parser <span class="ansiyellow">=</span> TextFileReader<span class="ansiyellow">(</span>filepath_or_buffer<span class="ansiyellow">,</span> <span class="ansiyellow">**</span>kwds<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    316</span> <span class="ansiyellow"></span>
# <span class="ansigreen">    317</span>     <span class="ansigreen">if</span> <span class="ansiyellow">(</span>nrows <span class="ansigreen">is</span> <span class="ansigreen">not</span> <span class="ansigreen">None</span><span class="ansiyellow">)</span> <span class="ansigreen">and</span> <span class="ansiyellow">(</span>chunksize <span class="ansigreen">is</span> <span class="ansigreen">not</span> <span class="ansigreen">None</span><span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">__init__</span><span class="ansiblue">(self, f, engine, **kwds)</span>
# <span class="ansigreen">    643</span>             self<span class="ansiyellow">.</span>options<span class="ansiyellow">[</span><span class="ansiblue">&apos;has_index_names&apos;</span><span class="ansiyellow">]</span> <span class="ansiyellow">=</span> kwds<span class="ansiyellow">[</span><span class="ansiblue">&apos;has_index_names&apos;</span><span class="ansiyellow">]</span><span class="ansiyellow"></span>
# <span class="ansigreen">    644</span> <span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 645</span><span class="ansiyellow">         </span>self<span class="ansiyellow">.</span>_make_engine<span class="ansiyellow">(</span>self<span class="ansiyellow">.</span>engine<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    646</span> <span class="ansiyellow"></span>
# <span class="ansigreen">    647</span>     <span class="ansigreen">def</span> close<span class="ansiyellow">(</span>self<span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">_make_engine</span><span class="ansiblue">(self, engine)</span>
# <span class="ansigreen">    797</span>     <span class="ansigreen">def</span> _make_engine<span class="ansiyellow">(</span>self<span class="ansiyellow">,</span> engine<span class="ansiyellow">=</span><span class="ansiblue">&apos;c&apos;</span><span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">    798</span>         <span class="ansigreen">if</span> engine <span class="ansiyellow">==</span> <span class="ansiblue">&apos;c&apos;</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 799</span><span class="ansiyellow">             </span>self<span class="ansiyellow">.</span>_engine <span class="ansiyellow">=</span> CParserWrapper<span class="ansiyellow">(</span>self<span class="ansiyellow">.</span>f<span class="ansiyellow">,</span> <span class="ansiyellow">**</span>self<span class="ansiyellow">.</span>options<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    800</span>         <span class="ansigreen">else</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">    801</span>             <span class="ansigreen">if</span> engine <span class="ansiyellow">==</span> <span class="ansiblue">&apos;python&apos;</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">__init__</span><span class="ansiblue">(self, src, **kwds)</span>
# <span class="ansigreen">   1211</span>         kwds<span class="ansiyellow">[</span><span class="ansiblue">&apos;allow_leading_cols&apos;</span><span class="ansiyellow">]</span> <span class="ansiyellow"

# %%
#Logistic regression
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from sklearn.preprocessing import MinMaxScaler, Imputer

# Drop the target from the training data
if 'TARGET' in app_train:
    train = app_train.drop(columns = ['TARGET'])
else:
    train = app_train.copy()
    
# Feature names
features = list(train.columns)

# Copy of the testing data
test = app_test.copy()

# Median imputation of missing values
imputer = Imputer(strategy = 'median')

# Scale each feature to 0-1
scaler = MinMaxScaler(feature_range = (0, 1))

# Fit on the training data
imputer.fit(train)

# Transform both training and testing data
train = imputer.transform(train)
test = imputer.transform(app_test)

# Repeat with the scaler
scaler.fit(train)
train = scaler.transform(train)
test = scaler.transform(test)

print('Training data shape: ', train.shape)
print('Testing data shape: ', test.shape)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">NameError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">&lt;command-498798941979528&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">      2</span> <span class="ansiyellow"></span>
# <span class="ansigreen">      3</span> <span class="ansired"># Drop the target from the training data</span><span class="ansiyellow"></span><span class="ansiyellow"></span>
# <span class="ansigreen">----&gt; 4</span><span class="ansiyellow"> </span><span class="ansigreen">if</span> <span class="ansiblue">&apos;TARGET&apos;</span> <span class="ansigreen">in</span> app_train<span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">      5</span>     train <span class="ansiyellow">=</span> app_train<span class="ansiyellow">.</span>drop<span class="ansiyellow">(</span>columns <span class="ansiyellow">=</span> <span class="ansiyellow">[</span><span class="ansiblue">&apos;TARGET&apos;</span><span class="ansiyellow">]</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">      6</span> <span class="ansigreen">else</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansired">NameError</span>: name &apos;app_train&apos; is not defined</div>

# %%
from sklearn.linear_model import LogisticRegression

# Make the model with the specified regularization parameter
log_reg = LogisticRegression(C = 0.0001)

# Train on the training data
log_reg.fit(train, train_labels)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">NameError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">&lt;command-1326330339456503&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">      5</span> <span class="ansiyellow"></span>
# <span class="ansigreen">      6</span> <span class="ansired"># Train on the training data</span><span class="ansiyellow"></span><span class="ansiyellow"></span>
# <span class="ansigreen">----&gt; 7</span><span class="ansiyellow"> </span>log_reg<span class="ansiyellow">.</span>fit<span class="ansiyellow">(</span>train<span class="ansiyellow">,</span> train_labels<span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansired">NameError</span>: name &apos;train&apos; is not defined</div>

# %%
log_reg_pred = log_reg.predict_proba(test)[:, 1]
submit = app_test[['SK_ID_CURR']]
submit['TARGET'] = log_reg_pred

submit.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">NameError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">&lt;command-1326330339456504&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">----&gt; 1</span><span class="ansiyellow"> </span>log_reg_pred <span class="ansiyellow">=</span> log_reg<span class="ansiyellow">.</span>predict_proba<span class="ansiyellow">(</span>test<span class="ansiyellow">)</span><span class="ansiyellow">[</span><span class="ansiyellow">:</span><span class="ansiyellow">,</span> <span class="ansicyan">1</span><span class="ansiyellow">]</span><span class="ansiyellow"></span>
# <span class="ansigreen">      2</span> submit <span class="ansiyellow">=</span> app_test<span class="ansiyellow">[</span><span class="ansiyellow">[</span><span class="ansiblue">&apos;SK_ID_CURR&apos;</span><span class="ansiyellow">]</span><span class="ansiyellow">]</span><span class="ansiyellow"></span>
# <span class="ansigreen">      3</span> submit<span class="ansiyellow">[</span><span class="ansiblue">&apos;TARGET&apos;</span><span class="ansiyellow">]</span> <span class="ansiyellow">=</span> log_reg_pred<span class="ansiyellow"></span>
# <span class="ansigreen">      4</span> <span class="ansiyellow"></span>
# <span class="ansigreen">      5</span> submit<span class="ansiyellow">.</span>head<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansired">NameError</span>: name &apos;test&apos; is not defined</div>

# %%
submit.to_csv('log_reg_baseline.csv', index = False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">NameError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">&lt;command-1326330339456505&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">----&gt; 1</span><span class="ansiyellow"> </span>submit<span class="ansiyellow">.</span>to_csv<span class="ansiyellow">(</span><span class="ansiblue">&apos;log_reg_baseline.csv&apos;</span><span class="ansiyellow">,</span> index <span class="ansiyellow">=</span> <span class="ansigreen">False</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansired">NameError</span>: name &apos;submit&apos; is not defined</div>

# %%
#PCA
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Initialize an empty array to hold feature importances
feature_importances = np.zeros(train.shape[1])

# Create the model with several hyperparameters
model = lgb.LGBMClassifier(objective='binary', boosting_type = 'goss', n_estimators = 10000, class_weight = 'balanced')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">NameError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">&lt;command-1326330339456512&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">      1</span> <span class="ansired"># Initialize an empty array to hold feature importances</span><span class="ansiyellow"></span><span class="ansiyellow"></span>
# <span class="ansigreen">----&gt; 2</span><span class="ansiyellow"> </span>feature_importances <span class="ansiyellow">=</span> np<span class="ansiyellow">.</span>zeros<span class="ansiyellow">(</span>train<span class="ansiyellow">.</span>shape<span class="ansiyellow">[</span><span class="ansicyan">1</span><span class="ansiyellow">]</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">      3</span> <span class="ansiyellow"></span>
# <span class="ansigreen">      4</span> <span class="ansired"># Create the model with several hyperparameters</span><span class="ansiyellow"></span><span class="ansiyellow"></span>
# <span class="ansigreen">      5</span> model <span class="ansiyellow">=</span> lgb<span class="ansiyellow">.</span>LGBMClassifier<span class="ansiyellow">(</span>objective<span class="ansiyellow">=</span><span class="ansiblue">&apos;binary&apos;</span><span class="ansiyellow">,</span> boosting_type <span class="ansiyellow">=</span> <span class="ansiblue">&apos;goss&apos;</span><span class="ansiyellow">,</span> n_estimators <span class="ansiyellow">=</span> <span class="ansicyan">10000</span><span class="ansiyellow">,</span> class_weight <span class="ansiyellow">=</span> <span class="ansiblue">&apos;balanced&apos;</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansired">NameError</span>: name &apos;train&apos; is not defined</div>

# %%
# Fit the model twice to avoid overfitting
for i in range(2):
    
    # Split into training and validation set
    train_features, valid_features, train_y, valid_y = train_test_split(train, train_labels, test_size = 0.25, random_state = i)
    
    # Train using early stopping
    model.fit(train_features, train_y, early_stopping_rounds=100, eval_set = [(valid_features, valid_y)], 
              eval_metric = 'auc', verbose = 200)
    
    # Record the feature importances
    feature_importances += model.feature_importances_
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">NameError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">&lt;command-1326330339456513&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">      3</span> <span class="ansiyellow"></span>
# <span class="ansigreen">      4</span>     <span class="ansired"># Split into training and validation set</span><span class="ansiyellow"></span><span class="ansiyellow"></span>
# <span class="ansigreen">----&gt; 5</span><span class="ansiyellow">     </span>train_features<span class="ansiyellow">,</span> valid_features<span class="ansiyellow">,</span> train_y<span class="ansiyellow">,</span> valid_y <span class="ansiyellow">=</span> train_test_split<span class="ansiyellow">(</span>train<span class="ansiyellow">,</span> train_labels<span class="ansiyellow">,</span> test_size <span class="ansiyellow">=</span> <span class="ansicyan">0.25</span><span class="ansiyellow">,</span> random_state <span class="ansiyellow">=</span> i<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">      6</span> <span class="ansiyellow"></span>
# <span class="ansigreen">      7</span>     <span class="ansired"># Train using early stopping</span><span class="ansiyellow"></span><span class="ansiyellow"></span>
#
# <span class="ansired">NameError</span>: name &apos;train_test_split&apos; is not defined</div>

# %%
# Make sure to average feature importances! 
feature_importances = feature_importances / 2
feature_importances = pd.DataFrame({'feature': list(train.columns), 'importance': feature_importances}).sort_values('importance', ascending = False)

feature_importances.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">NameError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">&lt;command-1326330339456514&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">      1</span> <span class="ansired"># Make sure to average feature importances!</span><span class="ansiyellow"></span><span class="ansiyellow"></span>
# <span class="ansigreen">----&gt; 2</span><span class="ansiyellow"> </span>feature_importances <span class="ansiyellow">=</span> feature_importances <span class="ansiyellow">/</span> <span class="ansicyan">2</span><span class="ansiyellow"></span>
# <span class="ansigreen">      3</span> feature_importances <span class="ansiyellow">=</span> pd<span class="ansiyellow">.</span>DataFrame<span class="ansiyellow">(</span><span class="ansiyellow">{</span><span class="ansiblue">&apos;feature&apos;</span><span class="ansiyellow">:</span> list<span class="ansiyellow">(</span>train<span class="ansiyellow">.</span>columns<span class="ansiyellow">)</span><span class="ansiyellow">,</span> <span class="ansiblue">&apos;importance&apos;</span><span class="ansiyellow">:</span> feature_importances<span class="ansiyellow">}</span><span class="ansiyellow">)</span><span class="ansiyellow">.</span>sort_values<span class="ansiyellow">(</span><span class="ansiblue">&apos;importance&apos;</span><span class="ansiyellow">,</span> ascending <span class="ansiyellow">=</span> <span class="ansigreen">False</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">      4</span> <span class="ansiyellow"></span>
# <span class="ansigreen">      5</span> feature_importances<span class="ansiyellow">.</span>head<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansired">NameError</span>: name &apos;feature_importances&apos; is not defined</div>

# %%
# Find the features with zero importance
zero_features = list(feature_importances[feature_importances['importance'] == 0.0]['feature'])
print('There are %d features with 0.0 importance' % len(zero_features))
feature_importances.tail()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">NameError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">&lt;command-1326330339456515&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">      1</span> <span class="ansired"># Find the features with zero importance</span><span class="ansiyellow"></span><span class="ansiyellow"></span>
# <span class="ansigreen">----&gt; 2</span><span class="ansiyellow"> </span>zero_features <span class="ansiyellow">=</span> list<span class="ansiyellow">(</span>feature_importances<span class="ansiyellow">[</span>feature_importances<span class="ansiyellow">[</span><span class="ansiblue">&apos;importance&apos;</span><span class="ansiyellow">]</span> <span class="ansiyellow">==</span> <span class="ansicyan">0.0</span><span class="ansiyellow">]</span><span class="ansiyellow">[</span><span class="ansiblue">&apos;feature&apos;</span><span class="ansiyellow">]</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">      3</span> print<span class="ansiyellow">(</span><span class="ansiblue">&apos;There are %d features with 0.0 importance&apos;</span> <span class="ansiyellow">%</span> len<span class="ansiyellow">(</span>zero_features<span class="ansiyellow">)</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">      4</span> feature_importances<span class="ansiyellow">.</span>tail<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansired">NameError</span>: name &apos;feature_importances&apos; is not defined</div>

# %%
def plot_feature_importances(df, threshold = 0.9):
  plt.rcParams['font.size'] = 18
    
    # Sort features according to importance
    df = df.sort_values('importance', ascending = False).reset_index()
    
    # Normalize the feature importances to add up to one
    df['importance_normalized'] = df['importance'] / df['importance'].sum()
    df['cumulative_importance'] = np.cumsum(df['importance_normalized'])

    # Make a horizontal bar chart of feature importances
    plt.figure(figsize = (10, 6))
    ax = plt.subplot()
    
    # Need to reverse the index to plot most important on top
    ax.barh(list(reversed(list(df.index[:15]))), 
            df['importance_normalized'].head(15), 
            align = 'center', edgecolor = 'k')
    
    # Set the yticks and labels
    ax.set_yticks(list(reversed(list(df.index[:15]))))
    ax.set_yticklabels(df['feature'].head(15))
    
    # Plot labeling
    plt.xlabel('Normalized Importance'); plt.title('Feature Importances')
    plt.show()
    
    # Cumulative importance plot
    plt.figure(figsize = (8, 6))
    plt.plot(list(range(len(df))), df['cumulative_importance'], 'r-')
    plt.xlabel('Number of Features'); plt.ylabel('Cumulative Importance'); 
    plt.title('Cumulative Feature Importance');
    plt.show();
    
    importance_index = np.min(np.where(df['cumulative_importance'] > threshold))
    print('%d features required for %0.2f of cumulative importance' % (importance_index + 1, threshold))
    
    return df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansicyan">  File </span><span class="ansigreen">&quot;&lt;command-1326330339456516&gt;&quot;</span><span class="ansicyan">, line </span><span class="ansigreen">5</span>
# <span class="ansiyellow">    df = df.sort_values(&apos;importance&apos;, ascending = False).reset_index()</span>
# <span class="ansigrey">    ^</span>
# <span class="ansired">IndentationError</span><span class="ansired">:</span> unexpected indent
# </div>

# %%
norm_feature_importances = plot_feature_importances(feature_importances)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">NameError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">&lt;command-1326330339456517&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">----&gt; 1</span><span class="ansiyellow"> </span>norm_feature_importances <span class="ansiyellow">=</span> plot_feature_importances<span class="ansiyellow">(</span>feature_importances<span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansired">NameError</span>: name &apos;plot_feature_importances&apos; is not defined</div>

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import Imputer
from sklearn.pipeline import Pipeline

# Make sure to drop the ids and target
train = train.drop(columns = ['SK_ID_CURR', 'TARGET'])
test = test.drop(columns = ['SK_ID_CURR'])

# Make a pipeline with imputation and pca
pipeline = Pipeline(steps = [('imputer', Imputer(strategy = 'median')),
             ('pca', PCA())])

# Fit and transform on the training data
train_pca = pipeline.fit_transform(train)

# transform the testing data
test_pca = pipeline.transform(test)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">NameError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">&lt;command-1326330339456507&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">      4</span> <span class="ansiyellow"></span>
# <span class="ansigreen">      5</span> <span class="ansired"># Make sure to drop the ids and target</span><span class="ansiyellow"></span><span class="ansiyellow"></span>
# <span class="ansigreen">----&gt; 6</span><span class="ansiyellow"> </span>train <span class="ansiyellow">=</span> train<span class="ansiyellow">.</span>drop<span class="ansiyellow">(</span>columns <span class="ansiyellow">=</span> <span class="ansiyellow">[</span><span class="ansiblue">&apos;SK_ID_CURR&apos;</span><span class="ansiyellow">,</span> <span class="ansiblue">&apos;TARGET&apos;</span><span class="ansiyellow">]</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">      7</span> test <span class="ansiyellow">=</span> test<span class="ansiyellow">.</span>drop<span class="ansiyellow">(</span>columns <span class="ansiyellow">=</span> <span class="ansiyellow">[</span><span class="ansiblue">&apos;SK_ID_CURR&apos;</span><span class="ansiyellow">]</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">      8</span> <span class="ansiyellow"></span>
#
# <span class="ansired">NameError</span>: name &apos;train&apos; is not defined</div>

# %%
# Extract the pca object
pca = pipeline.named_steps['pca']

# Plot the cumulative variance explained

plt.figure(figsize = (10, 8))
plt.plot(list(range(train.shape[1])), np.cumsum(pca.explained_variance_ratio_), 'r-')
plt.xlabel('Number of PC'); plt.ylabel('Cumulative Variance Explained');
plt.title('Cumulative Variance Explained with PCA');
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">NameError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">&lt;command-1326330339456508&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">      1</span> <span class="ansired"># Extract the pca object</span><span class="ansiyellow"></span><span class="ansiyellow"></span>
# <span class="ansigreen">----&gt; 2</span><span class="ansiyellow"> </span>pca <span class="ansiyellow">=</span> pipeline<span class="ansiyellow">.</span>named_steps<span class="ansiyellow">[</span><span class="ansiblue">&apos;pca&apos;</span><span class="ansiyellow">]</span><span class="ansiyellow"></span>
# <span class="ansigreen">      3</span> <span class="ansiyellow"></span>
# <span class="ansigreen">      4</span> <span class="ansired"># Plot the cumulative variance explained</span><span class="ansiyellow"></span><span class="ansiyellow"></span>
# <span class="ansigreen">      5</span> <span class="ansiyellow"></span>
#
# <span class="ansired">NameError</span>: name &apos;pipeline&apos; is not defined</div>
